# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.11/dist-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.11/dist-packages (from ucimlrepo) (2025.6.15)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
# Importa a biblioteca pandas para manipulação de dados em formato tabular
import pandas as pd

# Importa a função fetch_ucirepo da biblioteca ucimlrepo para buscar datasets do UCI Machine Learning Repository
from ucimlrepo import fetch_ucirepo

# Faz o download do conjunto de dados 'Breast Cancer Wisconsin (Diagnostic)' usando o ID 17 do repositório
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# Extrai os dados das características (features) do conjunto de dados
X = breast_cancer_wisconsin_diagnostic.data.features

# Extrai os dados dos rótulos (targets), ou seja, o diagnóstico de câncer
Y = breast_cancer_wisconsin_diagnostic.data.targets

# %%
display(Y)
# Out:
#     Diagnosis
# 0           M
# 1           M
# 2           M
# 3           M
# 4           M
# ..        ...
# 564         M
# 565         M
# 566         M
# 567         M
# 568         B
#
# [569 rows x 1 columns]

# %%
display(X)
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0       0.30010          0.14710     0.2419             0.07871  ...   25.380
# 1       0.08690          0.07017     0.1812             0.05667  ...   24.990
# 2       0.19740          0.12790     0.2069             0.05999  ...   23.570
# 3       0.24140          0.10520     0.2597             0.09744  ...   14.910
# 4       0.19800          0.10430     0.1809             0.05883  ...   22.540
# ..          ...              ...        ...                 ...  ...      ...
# 564     0.24390          0.13890     0.1726             0.05623  ...   25.450
# 565     0.14400          0.09791     0.1752             0.05533  ...   23.690
# 566     0.09251          0.05302     0.1590             0.05648  ...   18.980
# 567     0.35140          0.15200     0.2397             0.07016  ...   25.740
# 568     0.00000          0.00000     0.1587             0.05884  ...    9.456
#
#      texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# 0       17.33      184.60  2019.0      0.16220       0.66560      0.7119
# 1       23.41      158.80  1956.0      0.12380       0.18660      0.2416
# 2       25.53      152.50  1709.0      0.14440       0.42450      0.4504
# 3       26.50       98.87   567.7      0.20980       0.86630      0.6869
# 4       16.67      152.20  1575.0      0.13740       0.20500      0.4000
# ..        ...         ...     ...          ...           ...         ...
# 564     26.40      166.10  2027.0      0.14100       0.21130      0.4107
# 565     38.25      155.00  1731.0      0.11660       0.19220      0.3215
# 566     34.12      126.70  1124.0      0.11390       0.30940      0.3403
# 567     39.42      184.60  1821.0      0.16500       0.86810      0.9387
# 568     30.37       59.16   268.6      0.08996       0.06444      0.0000
#
#      concave_points3  symmetry3  fractal_dimension3
# 0             0.2654     0.4601             0.11890
# 1             0.1860     0.2750             0.08902
# 2             0.2430     0.3613             0.08758
# 3             0.2575     0.6638             0.17300
# 4             0.1625     0.2364             0.07678
# ..               ...        ...                 ...
# 564           0.2216     0.2060             0.07115
# 565           0.1628     0.2572             0.06637
# 566           0.1418     0.2218             0.07820
# 567           0.2650     0.4087             0.12400
# 568           0.0000     0.2871             0.07039
#
# [569 rows x 30 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %%
X_treinamento, X_teste, Y_treinamento, Y_teste = train_test_split(X, Y, test_size=0.25)

# %%
# Substitui os rótulos da coluna 'Diagnosis' no conjunto de teste.
# Converte 'M' (Maligno) para 1 e 'B' (Benigno) para 0, facilitando o uso em algoritmos de machine learning.
Y_teste = Y_teste.replace({'Diagnosis': {'M': 1, 'B': 0}})

# Faz a mesma substituição no conjunto de treinamento: 'M' vira 1, 'B' vira 0.
Y_treinamento = Y_treinamento.replace({'Diagnosis': {'M': 1, 'B': 0}})

# Imprime as formas (shape) das matrizes de entrada e saída do treinamento — útil para verificar se os dados estão coerentes.
print(f'{X_treinamento.shape, Y_treinamento.shape}\n')

# Imprime as formas dos dados de teste — ajuda a validar a divisão dos dados e visualizar o tamanho.
print(f'{X_teste.shape, Y_teste.shape}')
# Out:
# ((426, 30), (426, 1))
#
# ((143, 30), (143, 1))

# %%
X_treinamento.shape, Y_treinamento.shape
# Out:
# ((426, 30), (426, 1))

# %%
X_teste.shape, Y_teste.shape
# Out:
# ((143, 30), (143, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential

# %% [markdown]
# Após importação da biblioteca tensorflow é possível criar a rede neural, aqui é criado uma camada de entrada com formato de 30, pois são 30 caracteristicas que serão analisadas, a segunda camada densa com 16 unidades e a ultima camada a de saída com a função sigmoide.

# %%
# Cria uma rede neural sequencial — ou seja, onde cada camada é adicionada uma após a outra.
rede_neural = Sequential([

    # Define a camada de entrada com 30 características (features) — isso corresponde ao número de colunas nos dados.
    tf.keras.layers.InputLayer(shape = (30,)),

    # Adiciona uma camada densa (totalmente conectada) com 16 neurônios.
    # A função de ativação 'relu' ajuda a introduzir não-linearidade no modelo.
    # O inicializador 'random_uniform' define os pesos iniciais aleatoriamente, em uma distribuição uniforme.
    tf.keras.layers.Dense(units = 16, activation='relu', kernel_initializer='random_uniform'),


    # Adiciona a camada de saída com 1 neurônio, ideal para problemas binários (diagnóstico de câncer: maligno ou benigno).
    # A função de ativação 'sigmoid' retorna um valor entre 0 e 1, representando a probabilidade.
    tf.keras.layers.Dense(units = 1, activation='sigmoid')
])

# %%
rede_neural.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,357 (9.21 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,572 (6.14 KB)

# %% [markdown]
# 1. Model: "sequential"
# Indica que o modelo foi construído como uma sequência linear de camadas, ou seja, cada camada recebe os dados da camada anterior.
#
# 2. Layer (type)
# Aqui são listadas as camadas do modelo. No seu caso, duas delas são Dense, ou seja, totalmente conectadas:
#
# A primeira é a camada oculta com 16 neurônios.
#
# A segunda é a camada de saída, com apenas 1 neurônio para classificar o resultado.
#
# 3. Output Shape
# Mostra a forma da saída de cada camada:
#
# (None, 16) significa que a camada oculta produzirá 16 valores por entrada. O None representa o número de amostras (exemplos), que pode variar.
#
# (None, 1) indica que a camada de saída produzirá 1 valor por entrada — ideal para classificação binária (ex: câncer benigno ou maligno).
#
# 4. Param #
# Exibe o número de parâmetros treináveis da camada:
#
# A primeira camada possui 496 parâmetros, que são os pesos (30 inputs × 16 neurônios = 480) e os 16 bias.
#
# A segunda camada tem 17 parâmetros: 16 pesos (de cada neurônio anterior) + 1 bias.
#
# 5. Total params
# É a soma de todos os parâmetros treináveis do modelo, que dá 513.
#
# 6. Trainable params
# Quantidade de parâmetros que serão atualizados durante o treinamento (também 513, pois todos são treináveis).
#
# 7. Non-trainable params
# Esses seriam os parâmetros que o modelo não irá ajustar, mas como você não usou nenhuma camada com congelamento (como camadas pré-treinadas), o valor é 0.

# %%
# Compila o modelo definindo como ele será treinado.
# Isso inclui o algoritmo de otimização, a função de perda e as métricas de avaliação.

rede_neural.compile(

    # Otimizador 'adam' é um dos mais usados — ele ajusta os pesos automaticamente de forma eficiente.
    optimizer="adam",

    # A função de perda 'binary_crossentropy' mede o erro da rede em problemas de classificação binária.
    # Ela compara a saída prevista com o rótulo verdadeiro (0 ou 1), ajustando os pesos para minimizar esse erro.
    loss="binary_crossentropy",

    # Métrica 'binary_accuracy' calcula a proporção de previsões corretas (acertos) no treino e teste.
    # Assim você consegue acompanhar o desempenho da rede ao longo do treinamento.
    metrics=["binary_accuracy"]
)

# %%
rede_neural.fit(X_treinamento, Y_treinamento, batch_size = 10, epochs=100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0
# Epoch 100/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9287 - loss: 0.1664

# %% [markdown]
# Teste para ver se a rede neural acerta os resultados com os dados de testes, e a transformação dos valores em verdadeiro ou falso

# %%
previsoes = rede_neural.predict(X_teste)
previsoes = (previsoes > 0.5)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
previsoes
# Out:
# array([[False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False]])

# %%
Y_teste
# Out:
#      Diagnosis
# 511          0
# 161          1
# 85           1
# 484          0
# 459          0
# ..         ...
# 193          1
# 528          0
# 461          1
# 361          0
# 539          0
#
# [143 rows x 1 columns]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Após importar a biblioteca podemos ver que a porcentagem de acerto da rede neural é de 93%

# %%
accuracy_score(Y_teste, previsoes)
# Out:
# 0.9300699300699301

# %% [markdown]
# Matriz de confusão nos mostra que 84 benignos foram classificados como benignos e 4 que era benigno foi classificado como maligno, e nos mostra que 6 malignos foram classificados como benignos e 49 malignos foram classificados como malignos. A diagonal principal nos mostra a quantidade de acertos.

# %%
confusion_matrix(Y_teste, previsoes)
# Out:
# array([[93,  0],
#        [10, 40]])

# %%
84 + 49, 4 + 6
# Out:
# (133, 10)

# %%
rede_neural.evaluate(X_teste, Y_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.9333 - loss: 0.1406
# [0.14481264352798462, 0.9300699234008789]

# %% [markdown]
# Criação de mais uma camada oculta.

# %%
rede_neural = Sequential([
    tf.keras.layers.InputLayer(shape = (30,)),
    tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
    tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
    tf.keras.layers.Dense(units = 1, activation = 'sigmoid')
])

# %%
rede_neural.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 16)             │           496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 785 (3.07 KB)
#  Trainable params: 785 (3.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Criação de um otimizador que limita os pesos a 0.5

# %%
otimizador = tf.keras.optimizers.Adam(learning_rate = 0.001, clipvalue= 0.5)

# %%
rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy'])

# %%
rede_neural.fit(X_treinamento, Y_treinamento, batch_size = 10, epochs=100)
# Out:
# Epoch 1/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - binary_accuracy: 0.5083 - loss: 0.7413
# Epoch 2/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.6941 - loss: 0.5890
# Epoch 3/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8484 - loss: 0.4717
# Epoch 4/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8189 - loss: 0.4249
# Epoch 5/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8364 - loss: 0.3619
# Epoch 6/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.8982 - loss: 0.2992
# Epoch 7/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8767 - loss: 0.2823
# Epoch 8/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9075 - loss: 0.2537
# Epoch 9/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9138 - loss: 0.2299
# Epoch 10/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8973 - loss: 0.2612
# Epoch 11/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9217 - loss: 0.2456
# Epoch 12/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8665 - loss: 0.3334
# Epoch 13/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8843 - loss: 0.2983
# Epoch 14/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8927 - loss: 0.2916
# Epoch 15/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9019 - loss: 0.2262
# Epoch 16/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9184 - loss: 0.2097
# Epoch 17/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8981 - loss: 0.2681
# Epoch 18/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8487 - loss: 0.3323
# Epoch 19/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8618 - loss: 0.3587
# Epoch 20/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8923 - loss: 0.3012
# Epoch 21/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8592 - loss: 0.4179
# Epoch 22/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - binary_accuracy: 0.8857 - loss: 0.2438
# Epoch 23/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.9054 - loss: 0.2252
# Epoch 24/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8870 - loss: 0.2536
# Epoch 25/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8723 - loss: 0.3303
# Epoch 26/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8668 - loss: 0.3223
# Epoch 27/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8911 - loss: 0.2735
# Epoch 28/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8806 - loss: 0.3591
# Epoch 29/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9080 - loss: 0.2258
# Epoch 30/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9255 - loss: 0.2148
# Epoch 31/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8897 - loss: 0.3065
# Epoch 32/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8968 - loss: 0.2822
# Epoch 33/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9031 - loss: 0.2275
# Epoch 34/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9165 - loss: 0.2267
# Epoch 35/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8942 - loss: 0.2930
# Epoch 36/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9060 - loss: 0.2374
# Epoch 37/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9143 - loss: 0.2065
# Epoch 38/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - binary_accuracy: 0.8802 - loss: 0.4627
# Epoch 39/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8752 - loss: 0.3515
# Epoch 40/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9153 - loss: 0.2407
# Epoch 41/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - binary_accuracy: 0.8955 - loss: 0.2701
# Epoch 42/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8751 - loss: 0.3799
# Epoch 43/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9214 - loss: 0.2544
# Epoch 44/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.8962 - loss: 0.3454
# Epoch 45/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9059 - loss: 0.3280
# Epoch 46/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8677 - loss: 0.4191
# Epoch 47/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8957 - loss: 0.2767
# Epoch 48/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.8251 - loss: 0.4410
# Epoch 49/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9007 - loss: 0.2661
# Epoch 50/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8777 - loss: 0.3199
# Epoch 51/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8861 - loss: 0.3520
# Epoch 52/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8699 - loss: 0.3573
# Epoch 53/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9024 - loss: 0.2543
# Epoch 54/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8230 - loss: 0.5882
# Epoch 55/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9059 - loss: 0.2699
# Epoch 56/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9167 - loss: 0.2304
# Epoch 57/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9215 - loss: 0.2266
# Epoch 58/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9228 - loss: 0.1995
# Epoch 59/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9216 - loss: 0.2233
# Epoch 60/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8856 - loss: 0.3264
# Epoch 61/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8827 - loss: 0.3641
# Epoch 62/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.8823 - loss: 0.3157
# Epoch 63/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8909 - loss: 0.2734
# Epoch 64/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9050 - loss: 0.3710
# Epoch 65/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8862 - loss: 0.3134
# Epoch 66/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8717 - loss: 0.3661
# Epoch 67/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9183 - loss: 0.2713
# Epoch 68/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8997 - loss: 0.2901
# Epoch 69/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - binary_accuracy: 0.8800 - loss: 0.3243
# Epoch 70/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9268 - loss: 0.1712
# Epoch 71/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9013 - loss: 0.2962
# Epoch 72/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7959 - loss: 0.4504
# Epoch 73/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.8890 - loss: 0.2807
# Epoch 74/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9135 - loss: 0.2596
# Epoch 75/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.9248 - loss: 0.1937
# Epoch 76/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9207 - loss: 0.2002
# Epoch 77/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8761 - loss: 0.3012
# Epoch 78/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9083 - loss: 0.2273
# Epoch 79/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - binary_accuracy: 0.9199 - loss: 0.1892
# Epoch 80/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9342 - loss: 0.1895
# Epoch 81/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9217 - loss: 0.2041
# Epoch 82/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9264 - loss: 0.1761
# Epoch 83/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9132 - loss: 0.3410
# Epoch 84/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8580 - loss: 0.4058
# Epoch 85/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.9398 - loss: 0.1668
# Epoch 86/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9033 - loss: 0.2855
# Epoch 87/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8907 - loss: 0.3593
# Epoch 88/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9103 - loss: 0.2730
# Epoch 89/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8846 - loss: 0.3282
# Epoch 90/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.9273 - loss: 0.2364
# Epoch 91/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9512 - loss: 0.1760
# Epoch 92/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9095 - loss: 0.2765
# Epoch 93/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9392 - loss: 0.2091
# Epoch 94/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9145 - loss: 0.2336
# Epoch 95/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9165 - loss: 0.2488
# Epoch 96/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.8899 - loss: 0.2631
# Epoch 97/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.9247 - loss: 0.1840
# Epoch 98/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.9353 - loss: 0.1592
# Epoch 99/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - binary_accuracy: 0.9215 - loss: 0.2043
# Epoch 100/100
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - binary_accuracy: 0.8996 - loss: 0.2139

# %% [markdown]
# Mostra o valor de erro e da acuracia.

# %%
rede_neural.evaluate(X_teste, Y_teste)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - binary_accuracy: 0.9059 - loss: 0.2271
# [0.22440789639949799, 0.9090909361839294]

# %% [markdown]
# Acessando os pesos da primeira camada da rede neural.

# %%
pesos0 = rede_neural.layers[0].get_weights()

# %% [markdown]
# São 2 arrays pois mostra a conexao dos bias e a conexao de cada neuronio.

# %%
len(pesos0)
# Out:
# 2

# %% [markdown]
# Bias

# %%
len(pesos0[1])
# Out:
# 16

# %% [markdown]
# Camada

# %%
len(pesos0[0])
# Out:
# 30

# %%
pesos1 = rede_neural.layers[1].get_weights()
pesos1
# Out:
# [array([[ 7.32779503e-03,  2.51598023e-02, -4.74416167e-02,
#          -5.94427809e-03, -2.44779866e-02, -7.46315205e-03,
#           9.40982029e-02, -8.34434107e-03, -1.78458720e-01,
#          -1.28202409e-01,  4.44149040e-02,  2.23653652e-02,
#          -1.16575629e-01, -4.19271290e-02, -2.69146692e-02,
#          -1.45790964e-01],
#         [ 3.19474675e-02, -4.60997708e-02, -1.10468492e-02,
#           1.17854029e-03,  1.65749677e-02,  1.18358508e-02,
#          -8.26385692e-02],
#         [-4.72737767e-04, -2.15291511e-02,  3.26171964e-01,
#          -4.94139455e-02, -2.74692588e-02,  1.02987722e-01,
#          -1.09776497e-01, -7.78641552e-03,  7.32293576e-02,
#           4.33511660e-03, -2.19573621e-02, -1.64264701e-02,
#           2.20464915e-01, -1.17692621e-02,  1.08696083e-02,
#          -3.80781144e-02],
#         [-3.46752256e-03, -1.34743080e-02,  2.37196349e-02,
#          -2.79264580e-02, -2.64589190e-02,  3.06046270e-02,
#          -2.49209162e-02,  1.81663036e-03,  3.57742235e-03,
#          -1.48572326e-02,  3.77065577e-02, -1.13836750e-02,
#           3.38001288e-02,  1.72770284e-02, -3.85197997e-02,
#          -1.68896094e-02],
#         [-3.71159092e-02,  2.13229209e-02,  4.59232694e-03,
#          -3.33109684e-02, -5.96328415e-02,  1.20902779e-02,
#           7.73766562e-02,  1.65654682e-02, -7.93123692e-02,
#          -4.00327444e-01, -2.41879467e-02, -3.51660661e-02,
#          -4.50066626e-02, -5.09853736e-02, -2.65096966e-02,
#          -1.39211401e-01],
#         [ 4.56922129e-03,  6.55248016e-03, -3.00770290e-02,
#           4.15753834e-02,  2.12772526e-02,  4.05842178e-02,
#           7.66264275e-03,  2.80866511e-02,  3.35151441e-02,
#          -2.49362942e-02,  4.25467752e-02,  4.81449850e-02,
#           2.97781937e-02, -4.91174310e-03,  2.16922648e-02,
#           5.27714565e-03],
#         [-3.15585323e-02, -5.06477337e-03,  4.38930273e-01,
#           3.39732207e-02,  5.08967740e-03,  2.09849879e-01,
#           9.46343914e-02, -3.55232731e-02, -8.43398347e-02,
#          -1.63313821e-01, -3.61940861e-02, -1.41896894e-02,
#           1.22031535e-03,  8.11042450e-03, -3.96115892e-02,
#          -6.15524054e-02],
#         [-2.96570715e-02, -3.93916778e-02,  3.56981903e-01,
#          -2.74899062e-02, -5.34097143e-02,  1.35131180e-01,
#           3.74834500e-02, -1.03485584e-03, -1.79937351e-02,
#           4.96236421e-02, -4.74977009e-02, -9.39721707e-03,
#           9.14205983e-02, -1.39997164e-02, -4.25984673e-02,
#           4.86354157e-02]], dtype=float32),
#  array([-0.02722102, -0.00712225, -0.28230992, -0.00729917, -0.01594364,
#         -0.28173915, -0.14607427,  0.        , -0.14634804, -0.06738348,
#          0.        , -0.01631872,  0.24338174, -0.01223808, -0.02427021,
#          0.08276518], dtype=float32)]

# %%
pesos2 = rede_neural.layers[2].get_weights()
pesos2
# Out:
# [array([[ 0.3428888 ],
#         [-0.18503077],
#         [ 0.04680698],
#         [-0.2537931 ],
#         [-0.51957846],
#         [ 0.19347402],
#         [ 0.93487364],
#         [ 0.58801043],
#         [-0.04184119],
#         [-0.03214225],
#         [ 0.404696  ],
#         [ 0.25984997],
#         [-0.53378814],
#         [ 0.3623123 ],
#         [ 0.3594558 ],
#         [-0.05201236]], dtype=float32),
#  array([-0.23868278], dtype=float32)]
