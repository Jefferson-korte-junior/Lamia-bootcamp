# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %% [markdown]
# Gera um array de 10.000 valores distribuídos normalmente (média=0, desvio padrão=0.8)
#
# Calcula o valor abaixo do qual uma certa porcentagem de observações em um grupo

# %%
#Calcula o porcentil 50 dos valores
np.percentile(vals, 50)
# Out:
# np.float64(0.00024538527188322756)

# %%
#Calcula o porcentil 90 dos valores 
np.percentile(vals, 90)

# %%
#Calcula o porcentil 20 dos valores 
np.percentile(vals, 20)
# Out:
# np.float64(-0.42490027852083667)
